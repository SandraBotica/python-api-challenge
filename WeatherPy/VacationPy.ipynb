# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import hvplot.pandas
import pandas as pd
import numpy as np
import requests
import time
import json

import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   pacific grove  36.6177 -121.9166      7.23        74           0
# 1        1      bredasdorp -34.5322   20.0403     28.14        46           0
# 2        2        luziania -16.2525  -47.9503     24.83        76          64
# 3        3  ribeira grande  38.5167  -28.7000     15.43        82          40
# 4        4            lebu -37.6167  -73.6500     14.01        90          33
#
#    Wind Speed Country        Date
# 0        3.60      US  1674217197
# 1        7.50      ZA  1674217197
# 2        1.65      BR  1674217197
# 3        8.94      PT  1674217198
# 4        1.55      CL  1674216922

# %%
len(city_data_df)
# Out:
# 577

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot

map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    frame_width = 800,
    frame_height = 600,
    scale = 0.5,
    color = "City")

# Display the map
# YOUR CODE HERE

map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
Max_temp_ideal_df = city_data_df.loc[(city_data_df["Max Temp"] > 18) & (city_data_df["Max Temp"] < 28),: ]
Max_temp_ideal_df
# Out:
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2          2    luziania -16.2525  -47.9503     24.83        76          64
# 9          9    hermanus -34.4187   19.2345     26.00        70           0
# 10        10      namibe -15.1961   12.1522     26.17        64          97
# 15        15        abha  18.2164   42.5053     19.14        42          40
# 17        17   carnarvon -24.8667  113.6333     24.33        79           2
# ..       ...         ...      ...       ...       ...       ...         ...
# 560      560  kabin buri  13.9511  101.7177     26.17        42          43
# 561      561         sur  22.5667   59.5289     21.26        58          12
# 563      563        mitu   1.1983  -70.1733     21.55        92          91
# 566      566  carutapera  -1.1950  -46.0200     25.18        85         100
# 569      569    mabaruma   8.2000  -59.7833     23.88        85          62
#
#      Wind Speed Country        Date
# ...

# %%
Max_temp_Wind_Speed_ideal_df = Max_temp_ideal_df.loc[Max_temp_ideal_df["Wind Speed"] < 6,: ]
Max_temp_Wind_Speed_ideal_df
# Out:
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2          2    luziania -16.2525  -47.9503     24.83        76          64
# 9          9    hermanus -34.4187   19.2345     26.00        70           0
# 10        10      namibe -15.1961   12.1522     26.17        64          97
# 15        15        abha  18.2164   42.5053     19.14        42          40
# 24        24     rikitea -23.1203 -134.9692     24.97        71          87
# ..       ...         ...      ...       ...       ...       ...         ...
# 558      558    damietta  31.4165   31.8133     19.73        49           0
# 560      560  kabin buri  13.9511  101.7177     26.17        42          43
# 563      563        mitu   1.1983  -70.1733     21.55        92          91
# 566      566  carutapera  -1.1950  -46.0200     25.18        85         100
# 569      569    mabaruma   8.2000  -59.7833     23.88        85          62
#
#      Wind Speed Country        Date
# ...

# %%
Max_temp_Wind_Speed_cloudiness_ideal_df = Max_temp_Wind_Speed_ideal_df.loc[Max_temp_Wind_Speed_ideal_df["Cloudiness"] == 0,:]
Max_temp_Wind_Speed_cloudiness_ideal_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 9          9            hermanus -34.4187   19.2345     26.00        70
# 25        25                suez  29.9737   32.5263     22.53        18
# 38        38                chuy -33.6971  -53.4616     25.69        62
# 42        42               kapaa  22.0752 -159.3190     21.99        91
# 48        48                hilo  19.7297 -155.0900     24.60        81
# 140      140  comodoro rivadavia -45.8667  -67.5000     19.92        77
# 191      191                 gat  31.6100   34.7642     22.66        36
# 194      194       makakilo city  21.3469 -158.0858     22.88        86
# 220      220           ewa beach  21.3156 -158.0072     23.66        86
# 253      253           taoudenni  22.6783   -3.9836     24.12        16
# 305      305        marsa matruh  31.3525   27.2453     18.04        38
# 328      328              monywa  22.1167   95.1333     22.35        42
# ...

# %%
# Drop any rows with null values
Max_temp_Wind_Speed_cloudiness_ideal_df = Max_temp_Wind_Speed_cloudiness_ideal_df.dropna()

# Display sample data
Max_temp_Wind_Speed_cloudiness_ideal_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 9          9            hermanus -34.4187   19.2345     26.00        70
# 25        25                suez  29.9737   32.5263     22.53        18
# 38        38                chuy -33.6971  -53.4616     25.69        62
# 42        42               kapaa  22.0752 -159.3190     21.99        91
# 48        48                hilo  19.7297 -155.0900     24.60        81
# 140      140  comodoro rivadavia -45.8667  -67.5000     19.92        77
# 191      191                 gat  31.6100   34.7642     22.66        36
# 194      194       makakilo city  21.3469 -158.0858     22.88        86
# 220      220           ewa beach  21.3156 -158.0072     23.66        86
# 253      253           taoudenni  22.6783   -3.9836     24.12        16
# 305      305        marsa matruh  31.3525   27.2453     18.04        38
# 328      328              monywa  22.1167   95.1333     22.35        42
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = Max_temp_Wind_Speed_cloudiness_ideal_df[["City", "Country", "Lat", "Lng","Humidity"]].copy(deep=True)

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ''

# Display sample data
hotel_df
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 9              hermanus      ZA -34.4187   19.2345        70
# 25                 suez      EG  29.9737   32.5263        18
# 38                 chuy      UY -33.6971  -53.4616        62
# 42                kapaa      US  22.0752 -159.3190        91
# 48                 hilo      US  19.7297 -155.0900        81
# 140  comodoro rivadavia      AR -45.8667  -67.5000        77
# 191                 gat      IL  31.6100   34.7642        36
# 194       makakilo city      US  21.3469 -158.0858        86
# 220           ewa beach      US  21.3156 -158.0072        86
# 253           taoudenni      ML  22.6783   -3.9836        16
# 305        marsa matruh      EG  31.3525   27.2453        38
# 328              monywa      MM  22.1167   95.1333        42
# 330              jiwani      PK  25.0500   61.7417        30
# 401             rosetta      EG  31.4044   30.4164        51
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
from api_keys import geoapify_key

# %%
# Set parameters to search for a hotel

city = hotel_df["City"]
latitude = hotel_df["Lat"]
longitude = hotel_df["Lng"]
radius = 10000
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

params = {
    "categories":"accommodation.hotel",
    "filter": filters,
    "bias": bias,
    "apiKey": geoapify_key,
    "limit":limit
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    
    # Get the city's name
    # city = row["City"]
    
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    # print(name_address)
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
        # hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["categories"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# hermanus - nearest hotel: Aloe guest house
# suez - nearest hotel: No hotel found
# chuy - nearest hotel: Alerces
# kapaa - nearest hotel: Pono Kai Resort
# hilo - nearest hotel: Dolphin Bay Hotel
# comodoro rivadavia - nearest hotel: No hotel found
# gat - nearest hotel: No hotel found
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# ewa beach - nearest hotel: Hampton Inn & Suites Oahu/Kapolei
# taoudenni - nearest hotel: No hotel found
# marsa matruh - nearest hotel: صقور
# monywa - nearest hotel: Hotel Chindwin
# jiwani - nearest hotel: No hotel found
# rosetta - nearest hotel: No hotel found
# buraydah - nearest hotel: دنا للوحدات السكنية
# polis - nearest hotel: C & A Tourist Apartments
# damietta - nearest hotel: No hotel found
#                    City Country      Lat       Lng  Humidity  \
# 9              hermanus      ZA -34.4187   19.2345        70
# 25                 suez      EG  29.9737   32.5263        18
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
#     size = "",
    frame_width = 800,
    frame_height = 600,
    scale = 0.5,
    color = "City",
    hover_cols = ["Hotel Name","Country"])

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
